# %%
class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration


print("Song class created successfully.")
# Out:
# Song class created successfully.

# %%
favorite_song = Song(
    "Good Days",
    "SZA",
    279
)

print("Title:", favorite_song.title)
print("Artist:", favorite_song.artist)
print("Duration:", favorite_song.duration, "seconds")
# Out:
# Title: Good Days
# Artist: SZA
# Duration: 279 seconds

# %%
class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration

    def play_preview(self):
        print(
            f"Playing 30-second preview of "
            f"{self.title} by {self.artist}"
        )


favorite_song = Song("Good Days", "SZA", 279)

favorite_song.play_preview()
# Out:
# Playing 30-second preview of Good Days by SZA

# %%
class FoodOrder:
    def __init__(self, restaurant_name):
        self.restaurant_name = restaurant_name
        self.items = []
        self.total_price = 0

    def add_item(self, item, price):
        self.items.append(item)
        self.total_price += price


order = FoodOrder("Spice Villa")

order.add_item("Paneer Tikka", 280)
order.add_item("Butter Roti", 60)

print("Restaurant:", order.restaurant_name)
print("Items:", order.items)
print("Total price: ₹", order.total_price)
# Out:
# Restaurant: Spice Villa
# Items: ['Paneer Tikka', 'Butter Roti']
# Total price: ₹ 340

# %%
class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration
        self.play_count = 0

    def increment_play_count(self):
        self.play_count += 1


favorite_song = Song("Good Days", "SZA", 279)

favorite_song.increment_play_count()
favorite_song.increment_play_count()
favorite_song.increment_play_count()

print("Song:", favorite_song.title)
print("Play count:", favorite_song.play_count)
# Out:
# Song: Good Days
# Play count: 3
