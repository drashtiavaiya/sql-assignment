# %%
import math

number = 25
factorial_number = 5

print("Square root of", number, "is", math.sqrt(number))
print("Factorial of", factorial_number, "is", math.factorial(factorial_number))
print("Value of pi:", math.pi)
# Out:
# Square root of 25 is 5.0
# Factorial of 5 is 120
# Value of pi: 3.141592653589793

# %%
import math

number = 25
factorial_number = 5

print("Square root of", number, "is", math.sqrt(number))
print("Factorial of", factorial_number, "is", math.factorial(factorial_number))
print("Value of pi:", math.pi)
# Out:
# Square root of 25 is 5.0
# Factorial of 5 is 120
# Value of pi: 3.141592653589793

# %%
from datetime import datetime

date_input = input("Enter a date (YYYY-MM-DD): ")

date_value = datetime.strptime(date_input, "%Y-%m-%d")

print("Day of the week:", date_value.strftime("%A"))
# Out:
# Enter a date (YYYY-MM-DD):  2026-09-22
# Day of the week: Tuesday

# %%
# %%writefile insta_utils.py

def format_follower_count(count):
    if count >= 1000000:
        return f"{count / 1000000:.1f}M"
    elif count >= 1000:
        return f"{count / 1000:.1f}K"
    else:
        return str(count)
# Out:
# Writing insta_utils.py

# %%
# %%writefile use_insta_utils.py

from insta_utils import format_follower_count

print(format_follower_count(1500))
print(format_follower_count(2300000))
# Out:
# Writing use_insta_utils.py

# %%
# %run use_insta_utils.py
# Out:
# 1.5K
# 2.3M

# %%
# %%writefile session17_statistics.py

import statistics
import requests

numbers = [10, 20, 30, 40, 50]

average = statistics.mean(numbers)

print("Numbers:", numbers)
print("Average:", average)
print("Requests package imported successfully.")
# Out:
# Writing session17_statistics.py
