# %%
print("Name: Drashti Avaiya")
print("Favorite App: Spotify")
# Out:
# Name: Drashti Avaiya
# Favorite App: Spotify

# %%
import datetime

current_year = datetime.datetime.now().year
print("Current Year:", current_year)
# Out:
# Current Year: 2026
