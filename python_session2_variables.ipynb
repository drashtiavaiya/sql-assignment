# %%
user_name = "Drashti Avaiya"
fav_app = "Spotify"
daily_usage_hours = 8

print("User Name:", user_name)
print("Favorite App:", fav_app)
print("Daily Usage Hours:", daily_usage_hours)
# Out:
# User Name: Drashti Avaiya
# Favorite App: Spotify
# Daily Usage Hours: 8

# %%
product_name = "Samsung Galaxy S24"
price = 74999.0
is_available = True

print(product_name, "-", type(product_name))
print(price, "-", type(price))
print(is_available, "-", type(is_available))
# Out:
# Samsung Galaxy S24 - <class 'str'>
# 74999.0 - <class 'float'>
# True - <class 'bool'>

# %%
# Spotify studies the songs a user plays, likes, and skips.

"""
The recommendation system compares listening patterns,
music genres, artists, and saved playlists.
It then recommends songs with similar characteristics.
"""

print("Spotify recommendation system explained using comments.")
# Out:
# Spotify recommendation system explained using comments.

# %%
order_total = 849
delivery_region = "Surat"
discount_percent = 20

print(
    f"Order from {delivery_region} totals ₹{order_total} "
    f"with {discount_percent}% discount."
)
# Out:
# Order from Surat totals ₹849 with 20% discount.

# %%
incorrect_example = """
if True:
\tprint("Starting analysis")
    print("Data loaded")
"""

print("Incorrect example with mixed indentation:")
print(incorrect_example)

print("Corrected output:")

if True:
    print("Starting analysis")
    print("Data loaded")
# Out:
# Incorrect example with mixed indentation:
#
# if True:
# 	print("Starting analysis")
#     print("Data loaded")
#
# Corrected output:
# Starting analysis
# Data loaded
