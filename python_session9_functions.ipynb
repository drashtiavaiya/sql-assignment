# %%
def calculate_final_price(price, discount_rate):
    discount_amount = price * discount_rate
    final_price = price - discount_amount
    return final_price


result = calculate_final_price(1200, 0.15)

print("Final price:", result)
# Out:
# Final price: 1020.0

# %%
def get_delivery_charge(amount, city="Ahmedabad"):
    if city == "Ahmedabad":
        return 30
    else:
        return 50


print("With default city:", get_delivery_charge(500))
print("With another city:", get_delivery_charge(500, "Surat"))
# Out:
# With default city: 30
# With another city: 50

# %%
def format_coupon_message(username, discount=10):
    return f"Hi {username}, you get {discount}% off!"


print(format_coupon_message("Drashti", 20))
print(format_coupon_message("Rahul"))
# Out:
# Hi Drashti, you get 20% off!
# Hi Rahul, you get 10% off!

# %%
def apply_discount(price, rate=0.10):
    final_price = price - (price * rate)
    return final_price


print("Final price:", apply_discount(1500))
# Out:
# Final price: 1350.0

# %%
def calculate_cashback(amount, cashback_rate=0.05):
    cashback = amount * cashback_rate
    return cashback


print("Zomato cashback:", calculate_cashback(500))
print("Flipkart cashback:", calculate_cashback(2000, 0.07))
# Out:
# Zomato cashback: 25.0
# Flipkart cashback: 140.0
